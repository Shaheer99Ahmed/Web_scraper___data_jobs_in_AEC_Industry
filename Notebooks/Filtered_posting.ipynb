# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
file_path = "/content/Langan.xlsx"

# Read the data into a pandas DataFrame
df = pd.read_excel(file_path)

# %%
df1 = df[df['keywords_count'] > 3]

# Plotting a bar chart
plt.figure(figsize=(20, 6))
plt.bar(filtered_df['title'] + ' - ' + filtered_df['company'], filtered_df['keywords_count'])
plt.xlabel('Job Title - Company')
plt.ylabel('Keywords Count')
plt.title('Jobs with Keywords Count > 3')
plt.xticks(rotation=90)
plt.show()

# %%
import seaborn as sns
sns.violinplot(x='keywords_count', data=filtered_df)
plt.xlabel('Keywords Count')
plt.title('Distribution of Keywords Count')
plt.show()

# %%
df['keywords_count'] = pd.to_numeric(df['keywords_count'], errors='coerce')

# Filter rows where keywords_count is greater than 3
filtered_data = df[df['keywords_count'] > 3]

# Get the overall number of rows
overall_count = len(filtered_data)

print(f"The overall number of rows with keywords_count > 3 is: {overall_count}")
# Out:
# The overall number of rows with keywords_count > 3 is: 117
